# %%
ADS ASSIGNMENT-1

# %% [markdown]
# Importing the required libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Defing the functions

# %%
def countplot(dataframe, x_val, plot_title='', figsize=(15,8)):
    plt.figure(figsize=figsize)
    plt.title(plot_title)
    sns.countplot(data=df, x=x_val)
    plt.show()

# %%
def barplot(dataframe, x_val, y_val):
    sns.barplot(data=dataframe, x=x_val, y=y_val)
    plt.title(x_val.title() + ' vs ' + y_val.title())
    plt.show()

# %% [markdown]
# Reading and viewing the dataset

# %%
df = pd.read_csv('/content/House Price India (1).csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50       3650.0
# 1  6762810635  42491                   4                 2.50       2920.0
# 2  6762810998  42491                   5                 2.75       2910.0
# 3  6762812605  42491                   4                 2.50       3310.0
# 4  6762812919  42491                   3                 2.00       2710.0
#
#    lot area  number of floors  waterfront present  number of views  \
# 0    9050.0               2.0                 0.0              4.0
# 1    4000.0               1.5                 0.0              0.0
# 2    9480.0               1.5                 0.0              0.0
# 3   42998.0               2.0                 0.0              0.0
# 4    4500.0               1.5                 0.0              0.0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                     5.0  ...      1921.0              0.0     122003.0
# 1                     5.0  ...      1909.0              0.0     122004.0
# 2                     3.0  ...      1939.0              0.0     122004.0
# 3                     3.0  ...      2001.0              0.0     122005.0
# 4                     4.0  ...      1929.0              0.0     122006.0
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557             2880.0          5400.0
# 1    52.8878   -114.470             2470.0          4000.0
# 2    52.8852   -114.468             2940.0          6600.0
# 3    52.9532   -114.321             3350.0         42847.0
# 4    52.9047   -114.485             2060.0          4500.0
#
#    Number of schools nearby  Distance from the airport      Price
# 0                       2.0                       58.0  2380000.0
# 1                       2.0                       51.0  1400000.0
# 2                       1.0                       53.0  1200000.0
# 3                       3.0                       76.0   838000.0
# 4                       1.0                       51.0   805000.0
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 19184  6762830250  42734                   2                  1.5
# 19185  6762830339  42734                   3                  2.0
# 19186  6762830618  42734                   2                  1.0
# 19187  6762830709  42734                   4                  1.0
# 19188  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 19184       1556.0   20000.0               1.0                 0.0
# 19185       1680.0    7000.0               1.5                 0.0
# 19186       1070.0    6120.0               1.0                 0.0
# 19187       1030.0    6621.0               1.0                 0.0
# 19188        900.0    4770.0               1.0                 0.0
#
#        number of views  condition of the house  ...  Built Year  \
# 19184              0.0                     4.0  ...      1957.0
# 19185              0.0                     4.0  ...      1968.0
# 19186              0.0                     3.0  ...      1962.0
# 19187              0.0                     4.0  ...      1955.0
# 19188              0.0                     3.0  ...      1969.0
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 19184              0.0     122066.0    52.6191   -114.472             2250.0
# 19185              0.0     122072.0    52.5075   -114.393             1540.0
# 19186              0.0     122056.0    52.7289   -114.507             1130.0
# 19187              0.0     122042.0    52.7157   -114.411             1420.0
# 19188           2009.0     122018.0    52.5338   -114.552              900.0
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 19184         17286.0                       3.0                       76.0
# 19185          7480.0                       3.0                       59.0
# 19186          6120.0                       2.0                       64.0
# 19187          6631.0                       3.0                       54.0
# 19188          3480.0                       2.0                       55.0
#
#           Price
# 19184  221700.0
# 19185  219200.0
# 19186  209000.0
# 19187  205000.0
# 19188  146000.0
#
# [5 rows x 23 columns]

# %% [markdown]
# The dataset is loaded and found that there are 23 columns present in the given dataset

# %%
pd.DataFrame(list(df.columns), columns=['Column Name'])
# Out:
#                               Column Name
# 0                                      id
# 1                                    Date
# 2                      number of bedrooms
# 3                     number of bathrooms
# 4                             living area
# 5                                lot area
# 6                        number of floors
# 7                      waterfront present
# 8                         number of views
# 9                  condition of the house
# 10                     grade of the house
# 11  Area of the house(excluding basement)
# 12                   Area of the basement
# 13                             Built Year
# 14                        Renovation Year
# 15                            Postal Code
# 16                              Lattitude
# 17                              Longitude
# 18                      living_area_renov
# 19                         lot_area_renov
# 20               Number of schools nearby
# 21              Distance from the airport
# 22                                  Price

# %% [markdown]
# Exploratory Data Analysis

# %%
df.shape
# Out:
# (19189, 23)

# %% [markdown]
# It is founded that there are 14620 rows and 23 columns in the dataset
# Which means that there are 14620 data with 23 features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19189 entries, 0 to 19188
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     19189 non-null  int64
#  1   Date                                   19189 non-null  int64
#  2   number of bedrooms                     19189 non-null  int64
#  3   number of bathrooms                    19189 non-null  float64
#  4   living area                            19188 non-null  float64
#  5   lot area                               19188 non-null  float64
#  6   number of floors                       19188 non-null  float64
#  7   waterfront present                     19188 non-null  float64
#  8   number of views                        19188 non-null  float64
#  9   condition of the house                 19188 non-null  float64
#  10  grade of the house                     19188 non-null  float64
#  11  Area of the house(excluding basement)  19188 non-null  float64
#  12  Area of the basement                   19188 non-null  float64
#  13  Built Year                             19188 non-null  float64
#  14  Renovation Year                        19188 non-null  float64
#  15  Postal Code                            19188 non-null  float64
#  16  Lattitude                              19188 non-null  float64
#  17  Longitude                              19188 non-null  float64
#  18  living_area_renov                      19188 non-null  float64
#  19  lot_area_renov                         19188 non-null  float64
#  20  Number of schools nearby               19188 non-null  float64
#  21  Distance from the airport              19188 non-null  float64
#  22  Price                                  19188 non-null  float64
# dtypes: float64(20), int64(3)
# memory usage: 3.4 MB

# %% [markdown]
# Visualizations

# %%
countplot(dataframe=df, x_val='number of bedrooms', plot_title='Count of Number of Bedrooms')

# %% [markdown]
# From the above plot it is inferred that,
# There are more number of houses with 3 bedrooms and the houses with more than 7 bedrooms are very less in count.
# The second largest count of houses are with 4 number of bedrooms.

# %%
countplot(dataframe=df, x_val='number of bathrooms', plot_title='Count of Number of Bathrooms')

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses with 2.5 bathrooms, and the second is the houses with 1 bathrooms.
# Houses with 0.5, 1.25, and above 4.25 are very less in count.

# %%
countplot(dataframe=df, x_val='number of floors', figsize=(8,5), plot_title='Count of Number of Floors')

# %% [markdown]
# From the above plot it is inferred that,
# There are more houses with 1 floor.
# And the second largest number of homes are with 2 floors.
# We can see the homes with 2.5 and 3.5 floors are of least number of counts.

# %%
countplot(dataframe=df, x_val='waterfront present', figsize=(8,6), plot_title='Water present (1) or not (0)')

# %% [markdown]
# It is founded that there are more than 14000 houses without water in front.
# There are very less amount of home contains water in the front.

# %%
countplot(dataframe=df, x_val='number of views', figsize=(8,5), plot_title='Number of Views')

# %% [markdown]
# From the above plot it is inferred that,
# There are huge number of houses with 0 views.
# The second large number of houses are with 2 views.
# The houses with 1 and 4 views are very less in number.

# %%
countplot(dataframe=df, x_val='condition of the house', figsize=(8,5), plot_title='House Condition')

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses with normal condition that is the medium condition.
# The houses which have good conditions are less in count.
# There are very less number of houses which are in very worst conditions.

# %%
countplot(dataframe=df, x_val='grade of the house', figsize=(8,5), plot_title='Grade of the House')

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses with grade 7.
# Grade 8 houses are ranking two on count.
# The houses with grade 4 and 13 are very lesser in count.

# %%
countplot(dataframe=df, x_val='Number of schools nearby', figsize=(8,5), plot_title='Number of Schools Nearby')

# %% [markdown]
# From the above plot it is inferred that,
# There are houses which contains 3 schools in near are of higher number.
# The houses with 1 school nearby is slightly less in number compared to that of the other houses.

# %%
sns.displot(df['Price'])
plt.title('Price Distribution')
plt.show()

# %% [markdown]
# From the above plot it is inferred that,
# The plot is right skewed.
# This means that majority of the houses are less priced.

# %%
sns.histplot(data=df, x='Distance from the airport')
plt.show()

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses whose distance from the airport is near to the multiples of 5 ranging from 50 to 80 kms.
# The rest of the distanced houses from the airport are less in number when compared to the other houses.

# %%
sns.barplot(data=df, x='Number of schools nearby', y='Distance from the airport')
plt.title('Number of schools vs Distance from airport')
plt.show()

# %% [markdown]
# From the above plot it is inferred that,
# The number of schools and the Distance from airport from the houses are almost same.
# The distance from the airport to the house with schools are of more than 60 kms.

# %%
barplot(dataframe=df, x_val='number of bedrooms', y_val='number of bathrooms')

# %% [markdown]
# From the above plot it is inferred that,
# The number of bedrooms and the numbers of floors are somewhat similar.
# There isn't much variation between those two.

# %%
barplot(dataframe=df, x_val='number of floors', y_val='number of bathrooms')

# %%
barplot(dataframe=df, x_val='number of floors', y_val='number of bedrooms')

# %%
barplot(dataframe=df, x_val='condition of the house', y_val='grade of the house')

# %%
barplot(dataframe=df, x_val='number of views', y_val='grade of the house')

# %%
barplot(dataframe=df, x_val='condition of the house', y_val='number of views')

# %%
fig = plt.figure(figsize = [30, 18]) 

for i in range(1, len(list(df.columns))):
    plt.subplot(8, 3, i)
    
    fig.tight_layout(pad=2) 
    df_new = df.iloc[:,i]
    
    plt.suptitle('Comparision of all Features') 
    plt.title(list(df.columns)[i]) 
    sns.boxenplot(df_new) 

plt.show()

# %%
df.iloc[:,2:].describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        19189.000000         19189.000000  19188.000000  1.918800e+04
# mean             3.378290            26.933947   2092.236346  1.516591e+04
# std              0.996476          3436.925232    928.232550  3.810125e+04
# min              1.000000             0.500000    370.000000  5.200000e+02
# 25%              3.000000             1.750000   1430.000000  5.010750e+03
# 50%              3.000000             2.250000   1920.000000  7.580000e+03
# 75%              4.000000             2.500000   2560.000000  1.072000e+04
# max             51.000000        476100.000000  13540.000000  1.074218e+06
#
#        number of floors  waterfront present  number of views  \
# count      19188.000000        19188.000000     19188.000000
# mean           1.500365            0.007974         0.231655
# std            0.540172            0.088941         0.764338
# min            1.000000            0.000000         0.000000
# 25%            1.000000            0.000000         0.000000
# 50%            1.500000            0.000000         0.000000
# 75%            2.000000            0.000000         0.000000
# max            3.500000            1.000000         4.000000
#
#        condition of the house  grade of the house  \
# count            19188.000000        19188.000000
# mean                 3.424328            7.671097
# std                  0.661233            1.173874
# min                  1.000000            4.000000
# 25%                  3.000000            7.000000
# 50%                  3.000000            7.000000
# 75%                  4.000000            8.000000
# max                  5.000000           13.000000
#
#        Area of the house(excluding basement)  ...    Built Year  \
# count                           19188.000000  ...  19188.000000
# mean                             1797.074734  ...   1970.808943
# std                               833.943828  ...     29.463127
# min                               370.000000  ...   1900.000000
# 25%                              1200.000000  ...   1951.000000
# 50%                              1570.000000  ...   1975.000000
# 75%                              2230.000000  ...   1997.000000
# max                              9410.000000  ...   2015.000000
#
#        Renovation Year    Postal Code     Lattitude     Longitude  \
# count     19188.000000   19188.000000  19188.000000  19188.000000
# mean         90.169429  122033.139410     52.792055   -114.405235
# std         414.523600      19.080472      0.138494      0.140648
# min           0.000000  122003.000000     52.385900   -114.709000
# 25%           0.000000  122017.000000     52.704500   -114.519000
# 50%           0.000000  122032.000000     52.805800   -114.423000
# 75%           0.000000  122048.000000     52.909200   -114.316750
# max        2015.000000  122072.000000     53.007600   -113.505000
#
#        living_area_renov  lot_area_renov  Number of schools nearby  \
# count       19188.000000    19188.000000              19188.000000
# mean         1989.118407    12800.054617                  2.011570
# std           688.228385    26621.090847                  0.817202
# min           460.000000      651.000000                  1.000000
# 25%          1490.000000     5100.000000                  1.000000
# 50%          1840.000000     7614.000000                  2.000000
# 75%          2370.000000    10079.250000                  3.000000
# max          6110.000000   560617.000000                  3.000000
#
#        Distance from the airport         Price
# count               19188.000000  1.918800e+04
# mean                   64.980769  5.362771e+05
# std                     8.941492  3.688292e+05
# min                    50.000000  7.800000e+04
# 25%                    57.000000  3.199000e+05
# 50%                    65.000000  4.490000e+05
# 75%                    73.000000  6.400000e+05
# max                    80.000000  7.700000e+06
#
# [8 rows x 21 columns]
